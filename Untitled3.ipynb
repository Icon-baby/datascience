# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import joblib

# %%
manu = pd.read_csv('accident.csv')

# %%
X = manu[['Number_of_vehicles_involved']]
y = manu['Number_of_casualties']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# 0.8994300323888089

# %%
print(regressor.coef_)
# Out:
# [0.31687184]

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([1.85004555, 1.53317371, 1.53317371, ..., 1.85004555, 1.53317371,
#        1.53317371])

# %%
y_test.head(10)
# Out:
# 8348    1
# 5386    1
# 1783    1
# 7077    3
# 5437    5
# 3981    2
# 9605    2
# 1766    1
# 4000    1
# 3749    1
# Name: Number_of_casualties, dtype: int64

# %%
from sklearn import metrics
import numpy as np
# Assuming y_test and y_pred are NumPy arrays or Pandas Series
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse) # RMSE is the square root of MSE
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 0.7341233418108433
# Mean Squared Error (MSE): 1.0466628265468803
# Root Mean Squared Error (RMSE): 1.023065406778511

# %%
import pickle
model = LinearRegression()
model.fit(X, y)
joblib.dump(model, 'accident_severity_model.pkl')
# Out:
# ['accident_severity_model.pkl']

# %%
import numpy as np
#Sample X values for prediction
new_X = np.array([10, 20, 30, 40, 50]).reshape(-1, 1) # Reshape to a 2D array
#Load the trained model
model = joblib.load('accident_severity_model.pkl') # Load your trained model here #Make predictions on the new X values
predictions = model.predict(new_X)
# Create a Dataframe with one-dimensional arrays
new_data = pd.DataFrame({'X': new_X.flatten(), 'Predicted_Y': predictions.flatten()})
# Display the new data DataFrame with the X values and the predicted V values print(new_data)
print(new_data)
# Out:
#     X  Predicted_Y
# 0  10     4.032111
# 1  20     7.152933
# 2  30    10.273754
# 3  40    13.394576
# 4  50    16.515398
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
